# %% [markdown]
# # Retrieval-Augmented Generation (RAG)

# %%
import chromadb
import dotenv
from pathlib import Path
from agents import Agent, Runner, function_tool, trace

dotenv.load_dotenv()
# Out:
# True

# %% [markdown]
# Create a static calorie table that we can use as a tool:

# %%
# We populated the RAG with the data from the data/calories.csv file in
# the rag_setup.ipynb notebook

chroma_client = chromadb.PersistentClient("../chroma")
nutrition_db = chroma_client.get_collection(name="nutrition_db")

# %%
results = nutrition_db.query(query_texts=["banana"], n_results=2)
for i, doc in enumerate(results["documents"][0]):
    print(sorted(results["metadatas"][0][i].items()))
    print(doc)
    print("\n")
# Out:
# [('calories_per_100g', 89.0), ('food_category', 'fruits'), ('food_item', 'banana'), ('keywords', 'banana_fruits'), ('kj_per_100g', 374.0), ('serving_info', '100g')]
# Food: Banana
#         Category: Fruits
#         Nutritional Information:
#         - Calories: 89 per 100g
#         - Energy: 374 kJ per 100g
#         - Serving size reference: 100g
#
#         This is a fruits food item that provides 89 calories per 100 grams.
#
#
# [('calories_per_100g', 50.0), ('food_category', '(fruit)juices'), ('food_item', 'banana juice'), ('keywords', 'banana_juice_(fruit)juices'), ('kj_per_100g', 210.0), ('serving_info', '100ml')]
# Food: Banana Juice
#         Category: (Fruit)Juices
#         Nutritional Information:
#         - Calories: 50 per 100g
#         - Energy: 210 kJ per 100g
#         - Serving size reference: 100ml
#
#         This is a (fruit)juices food item that provides 50 calories per 100 grams.

# %%
@function_tool
def calorie_lookup_tool(query: str, max_results: int = 3) -> str:
    """
    Tool function for a RAG database to look up calorie information for specific food items, but not for meals.

    Args:
        query: The food item to look up.
        max_results: The maximum number of results to return.

    Returns:
        A string containing the nutrition information.
    """

    results = nutrition_db.query(query_texts=[query], n_results=max_results)

    if not results["documents"][0]:
        return f"No nutrition information found for: {query}"

    # Format results for the agent
    formatted_results = []
    for i, doc in enumerate(results["documents"][0]):
        metadata = results["metadatas"][0][i]
        food_item = metadata["food_item"].title()
        calories = metadata["calories_per_100g"]
        category = metadata["food_category"].title()

        formatted_results.append(
            f"{food_item} ({category}): {calories} calories per 100g"
        )

    return "Nutrition Information:\n" + "\n".join(formatted_results)

# %% [markdown]
# Let's test this out:
#
# _The following cell only works before you add the `@function_tool` annotation to `calorie_lookup_tool` function_

# %%
# calorie_lookup_tool('bananas')

# %%
calorie_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful nutrition assistant giving out calorie information.
    You give concise answers.
    If you need to look up calorie information, use the calorie_lookup_tool.
    """,
    tools=[calorie_lookup_tool],
)

# %%
with trace("Nutrition Assistant with RAG"):
    result = await Runner.run(
        calorie_agent,
        "How many calories are in total in a banana and an apple? Also give calories per 100g",
    )
    print(result.final_output)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[15], line 2
#       1 with trace("Nutrition Assistant with RAG"):
# ----> 2     result = await Runner.run(
#       3         calorie_agent,
#       4         "How many calories are in total in a banana and an apple? Also give calories per 100g",
#       5     )
#       6     print(result.final_output)
#
# File /workspaces/Ai-Agent-course/.venv/lib/python3.13/site-packages/agents/run.py:274, in Runner.run(cls, starting_agent, input, context, max_turns, hooks, run_config, previous_response_id, conversation_id, session)
#     240 """Run a workflow starting at the given agent. The agent will run in a loop until a final
#     241 output is generated. The loop runs like so:
#     242 1. The agent is invoked with the given input.
#    (...)    271     agent. Agents may perform handoffs, so we don't know the specific type of the output.
#     272 """
#     273 runner = DEFAULT_AGENT_RUNNER
# --> 274 return await runner.run(
#     275     starting_agent,
#     276     input,
#     277     context=context,
#     278     max_turns=max_turns,
#     279     hooks=hooks,
#     280     run_config=run_config,
#     281     previous_response_id=previous_response_id,
#     282     conversation_id=conversation_id,
#     283     session=session,
#     284 )
#
# File /workspaces/Ai-Agent-course/.venv/lib/python3.13/site-packages/agents/run.py:494, in AgentRunner.run(self, starting_agent, input, **kwargs)
#     489 logger.debug(
#     490     f"Running agent {current_agent.name} (turn {current_turn})",
#     491 )
#     493 if current_turn == 1:
# --> 494     input_guardrail_results, turn_result = await asyncio.gather(
#     495         self._run_input_guardrails(
#     496             starting_agent,
#     497             starting_agent.input_guardrails
#     498             + (run_config.input_guardrails or []),
#     499             _copy_str_or_list(prepared_input),
#     500             context_wrapper,
#     501         ),
#     502         self._run_single_turn(
#     503             agent=current_agent,
#     504             all_tools=all_tools,
#     505             original_input=original_input,
#     506             generated_items=generated_items,
#     507             hooks=hooks,
#     508             context_wrapper=context_wrapper,
#     509             run_config=run_config,
#     510             should_run_agent_start_hooks=should_run_agent_start_hooks,
#     511             tool_use_tracker=tool_use_tracker,
#     512             previous_response_id=previous_response_id,
#     513             conversation_id=conversation_id,
#     514         ),
#     515     )
#     516 else:
#     517     turn_result = await self._run_single_turn(
#     518         agent=current_agent,
#     519         all_tools=all_tools,
#    (...)    528         conversation_id=conversation_id,
#     529     )
#
# File /workspaces/Ai-Agent-course/.venv/lib/python3.13/site-packages/agents/run.py:1165, in AgentRunner._run_single_turn(cls, agent, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, previous_response_id, conversation_id)
#    1162 input = ItemHelpers.input_to_new_input_list(original_input)
#    1163 input.extend([generated_item.to_input_item() for generated_item in generated_items])
# -> 1165 new_response = await cls._get_new_response(
#    1166     agent,
#    1167     system_prompt,
#    1168     input,
#    1169     output_schema,
#    1170     all_tools,
#    1171     handoffs,
#    1172     hooks,
#    1173     context_wrapper,
#    1174     run_config,
#    1175     tool_use_tracker,
#    1176     previous_response_id,
#    1177     conversation_id,
#    1178     prompt_config,
#    1179 )
#    1181 return await cls._get_single_step_result_from_response(
#    1182     agent=agent,
#    1183     original_input=original_input,
#    (...)   1192     tool_use_tracker=tool_use_tracker,
#    1193 )
#
# File /workspaces/Ai-Agent-course/.venv/lib/python3.13/site-packages/agents/run.py:1385, in AgentRunner._get_new_response(cls, agent, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, previous_response_id, conversation_id, prompt_config)
#    1359 @classmethod
#    1360 async def _get_new_response(
#    1361     cls,
#    (...)   1375 ) -> ModelResponse:
#    1376     # Allow user to modify model input right before the call, if configured
#    1377     filtered = await cls._maybe_filter_model_input(
#    1378         agent=agent,
#    1379         run_config=run_config,
#    (...)   1382         system_instructions=system_prompt,
#    1383     )
# -> 1385     model = cls._get_model(agent, run_config)
#    1386     model_settings = agent.model_settings.resolve(run_config.model_settings)
#    1387     model_settings = RunImpl.maybe_reset_tool_choice(agent, tool_use_tracker, model_settings)
#
# File /workspaces/Ai-Agent-course/.venv/lib/python3.13/site-packages/agents/run.py:1481, in AgentRunner._get_model(cls, agent, run_config)
#    1478 elif isinstance(agent.model, Model):
#    1479     return agent.model
# -> 1481 return run_config.model_provider.get_model(agent.model)
#
# File /workspaces/Ai-Agent-course/.venv/lib/python3.13/site-packages/agents/models/multi_provider.py:144, in MultiProvider.get_model(self, model_name)
#     142     return provider.get_model(model_name)
#     143 else:
# --> 144     return self._get_fallback_provider(prefix).get_model(model_name)
#
# File /workspaces/Ai-Agent-course/.venv/lib/python3.13/site-packages/agents/models/openai_provider.py:87, in OpenAIProvider.get_model(self, model_name)
#      84 if model_name is None:
#      85     model_name = get_default_model()
# ---> 87 client = self._get_client()
#      89 return (
#      90     OpenAIResponsesModel(model=model_name, openai_client=client)
#      91     if self._use_responses
#      92     else OpenAIChatCompletionsModel(model=model_name, openai_client=client)
#      93 )
#
# File /workspaces/Ai-Agent-course/.venv/lib/python3.13/site-packages/agents/models/openai_provider.py:73, in OpenAIProvider._get_client(self)
#      71 def _get_client(self) -> AsyncOpenAI:
#      72     if self._client is None:
# ---> 73         self._client = _openai_shared.get_default_openai_client() or AsyncOpenAI(
#      74             api_key=self._stored_api_key or _openai_shared.get_default_openai_key(),
#      75             base_url=self._stored_base_url,
#      76             organization=self._stored_organization,
#      77             project=self._stored_project,
#      78             http_client=shared_http_client(),
#      79         )
#      81     return self._client
#
# File /workspaces/Ai-Agent-course/.venv/lib/python3.13/site-packages/openai/_client.py:480, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     478     api_key = os.environ.get("OPENAI_API_KEY")
#     479 if api_key is None:
# --> 480     raise OpenAIError(
#     481         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     482     )
#     483 if callable(api_key):
#     484     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
